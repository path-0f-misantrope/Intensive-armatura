# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
df = pd.read_csv('/content/result.csv', parse_dates=['dt'],)

# %%
data = pd.read_csv('/content/result.csv', parse_dates=['dt'], index_col='dt')
plt.figure(figsize = (15,10))
sns.heatmap(data = data.isnull(),cmap="YlGnBu_r",cbar=False)
# Out:
# <Axes: ylabel='dt'>

# %%
# !pip install statsmodels==0.14.4
# Out:
# Requirement already satisfied: statsmodels==0.14.4 in /usr/local/lib/python3.11/dist-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels==0.14.4) (2.0.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.11/dist-packages (from statsmodels==0.14.4) (1.14.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from statsmodels==0.14.4) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels==0.14.4) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels==0.14.4) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.4) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.4) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels==0.14.4) (1.17.0)

# %%
df['month'].head()
# Out:
# 0    2015-01
# 1    2015-01
# 2    2015-01
# 3    2015-01
# 4    2015-02
# Name: month, dtype: object

# %%
df['dt'] = pd.to_datetime(df['dt'])
df.drop(columns=["month"], inplace=True, errors="ignore")
df['month'] = df['dt'].dt.month
df['month'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    2
# Name: month, dtype: int32

# %%
print(df['Цена на арматуру'].describe())  # Основные статистики
print(df['Цена на арматуру'].isnull().sum())
# Out:
# count      400.000000
# mean     39229.475000
# std      13407.979668
# min      21000.000000
# 25%      31075.000000
# 50%      35450.000000
# 75%      42000.000000
# max      79000.000000
# Name: Цена на арматуру, dtype: float64
# 0

# %%
# Построение boxplot для анализа сезонности по месяцам
plt.figure(figsize=(18, 10))
sns.boxplot(x=df['month'], y=df['Цена на арматуру'])  # Передаем данные напрямую
plt.title('Сезонность цен на арматуру по месяцам')
plt.xlabel('Месяц')
plt.yscale('log')  # Логарифмический масштаб для оси Y
plt.show()

# %% [markdown]
# Диапазон цен:
#
# Цены на арматуру варьируются от примерно 20 000 до 60 000 (единицы измерения не указаны, предположительно рубли).
#
# На графике видно, что в некоторые месяцы цены достигают 60 000, а в другие опускаются до 20 000.
#
# Сезонность:
#
# График показывает, что цены на арматуру меняются в зависимости от месяца.
#
# Например, в месяцы 1, 2, 3 (январь, февраль, март) цены находятся в среднем диапазоне.
#
# В месяцы 6, 7, 8 (июнь, июль, август) цены могут быть выше, что может указывать на сезонный спрос.
#
# Выбросы:
#
# На графике видны выбросы (точки за пределами "усов" boxplot), особенно в месяцах 5, 6, 7, 8.
#
# Это может указывать на нестабильность цен в эти периоды или на аномальные значения.
#
# Логарифмический масштаб:
#
# Ось Y (Цена на арматуру) использует логарифмический масштаб, что помогает лучше видеть изменения при большом разбросе значений.

# %%
# Оставляем только числовые данные для анализа
df_numeric = df.select_dtypes(include=["number"])

# Проверяем корреляцию
correlation_matrix = df_numeric.corr()
print(correlation_matrix)
# Out:
#                                                 Цена на арматуру   Price_x  \
# Цена на арматуру                                        1.000000  0.712148
# Price_x                                                 0.712148  1.000000
# Open_x                                                  0.749590  0.995103
# High_x                                                  0.737547  0.997186
# Low_x                                                   0.723395  0.998380
# ...                                                          ...       ...
# Экспорт сырья Чугун_Передельный чугун                   0.659158  0.777963
# Экспорт арматуры Сортовой прокат_Арматура               0.615961  0.723272
# Экспорт арматуры Сортовой прокат_Катанка                0.683340  0.759985
# Экспорт арматуры Сортовой прокат_Прутки прочие         -0.043717 -0.117278
# month                                                  -0.011973 -0.026898
#
#                                                   Open_x    High_x     Low_x  \
# Цена на арматуру                                0.749590  0.737547  0.723395
# Price_x                                         0.995103  0.997186  0.998380
# Open_x                                          1.000000  0.998954  0.996093
# High_x                                          0.998954  1.000000  0.996227
# Low_x                                           0.996093  0.996227  1.000000
# ...                                                  ...       ...       ...
# Экспорт сырья Чугун_Передельный чугун           0.779960  0.774661  0.784654
# Экспорт арматуры Сортовой прокат_Арматура       0.726843  0.720093  0.732079
# Экспорт арматуры Сортовой прокат_Катанка        0.761062  0.758229  0.758518
# Экспорт арматуры Сортовой прокат_Прутки прочие -0.115834 -0.111277 -0.123669
# month                                          -0.035655 -0.037214 -0.022128
#
#                                                   Vol._x  Change %_x  \
# Цена на арматуру                                0.258057   -0.493949
# Price_x                                         0.315554   -0.121125
# Open_x                                          0.323669   -0.211418
# High_x                                          0.336116   -0.180209
# Low_x                                           0.295968   -0.151580
# ...                                                  ...         ...
# Экспорт сырья Чугун_Передельный чугун           0.285107   -0.185268
# Экспорт арматуры Сортовой прокат_Арматура       0.312377   -0.203124
# Экспорт арматуры Сортовой прокат_Катанка        0.132574   -0.117936
# Экспорт арматуры Сортовой прокат_Прутки прочие -0.144321    0.075082
# month                                           0.037320    0.066116
#
#                                                     Цена     Откр.     Макс.  \
# Цена на арматуру                                0.600969  0.638173  0.627784
# Price_x                                         0.952025  0.956118  0.956003
# Open_x                                          0.941072  0.953710  0.951100
# High_x                                          0.944550  0.954587  0.953707
# Low_x                                           0.949566  0.955439  0.953539
# ...                                                  ...       ...       ...
# Экспорт сырья Чугун_Передельный чугун           0.699368  0.708584  0.702524
# Экспорт арматуры Сортовой прокат_Арматура       0.652157  0.662389  0.655125
# Экспорт арматуры Сортовой прокат_Катанка        0.716507  0.725875  0.719920
# Экспорт арматуры Сортовой прокат_Прутки прочие -0.120276 -0.119927 -0.116225
# month                                          -0.067486 -0.072345 -0.074440
#
#                                                 ...  \
# Цена на арматуру                                ...
# Price_x                                         ...
# Open_x                                          ...
# High_x                                          ...
# Low_x                                           ...
# ...                                             ...
# Экспорт сырья Чугун_Передельный чугун           ...
# Экспорт арматуры Сортовой прокат_Арматура       ...
# Экспорт арматуры Сортовой прокат_Катанка        ...
# Экспорт арматуры Сортовой прокат_Прутки прочие  ...
# month                                           ...
#
#                                                 Экспорт сырья Кокс_Орешек коксовый  \
# Цена на арматуру                                                          0.096637
# Price_x                                                                  -0.202575
# Open_x                                                                   -0.169022
# High_x                                                                   -0.187638
# Low_x                                                                    -0.182435
# ...                                                                            ...
# Экспорт сырья Чугун_Передельный чугун                                    -0.185378
# Экспорт арматуры Сортовой прокат_Арматура                                -0.122434
# Экспорт арматуры Сортовой прокат_Катанка                                 -0.066448
# Экспорт арматуры Сортовой прокат_Прутки прочие                           -0.438838
# month                                                                    -0.101232
#
#                                                 Экспорт сырья Концентрат коксующегося угля_Жирные  \
# Цена на арматуру                                                                         0.202147
# Price_x                                                                                 -0.086119
# Open_x                                                                                  -0.048158
# High_x                                                                                  -0.066869
# Low_x                                                                                   -0.063332
# ...                                                                                           ...
# Экспорт сырья Чугун_Передельный чугун                                                    0.139214
# Экспорт арматуры Сортовой прокат_Арматура                                                0.300405
# Экспорт арматуры Сортовой прокат_Катанка                                                -0.230124
# Экспорт арматуры Сортовой прокат_Прутки прочие                                          -0.670925
# month                                                                                    0.026219
#
#                                                 Экспорт сырья Концентрат коксующегося угля_Коксовые  \
# Цена на арматуру                                                                         0.602053
# Price_x                                                                                  0.485383
# Open_x                                                                                   0.511821
# High_x                                                                                   0.497011
# Low_x                                                                                    0.501536
# ...                                                                                           ...
# Экспорт сырья Чугун_Передельный чугун                                                    0.630730
# Экспорт арматуры Сортовой прокат_Арматура                                                0.716044
# Экспорт арматуры Сортовой прокат_Катанка                                                 0.424077
# Экспорт арматуры Сортовой прокат_Прутки прочие                                          -0.533389
# month                                                                                    0.105991
#
#                                                 Экспорт сырья Лом_Лом стальной  \
# Цена на арматуру                                                           NaN
# Price_x                                                                    NaN
# Open_x                                                                     NaN
# High_x                                                                     NaN
# Low_x                                                                      NaN
# ...                                                                        ...
# Экспорт сырья Чугун_Передельный чугун                                      NaN
# Экспорт арматуры Сортовой прокат_Арматура                                  NaN
# Экспорт арматуры Сортовой прокат_Катанка                                   NaN
# Экспорт арматуры Сортовой прокат_Прутки прочие                             NaN
# month                                                                      NaN
#
#                                                 Экспорт сырья Чугун_Литейный чугун  \
# Цена на арматуру                                                          0.360503
# Price_x                                                                  -0.128088
# Open_x                                                                   -0.084881
# High_x                                                                   -0.090620
# Low_x                                                                    -0.129948
# ...                                                                            ...
# Экспорт сырья Чугун_Передельный чугун                                    -0.171174
# Экспорт арматуры Сортовой прокат_Арматура                                -0.233113
# Экспорт арматуры Сортовой прокат_Катанка                                  0.112229
# Экспорт арматуры Сортовой прокат_Прутки прочие                            0.316216
# month                                                                    -0.104334
#
#                                                 Экспорт сырья Чугун_Передельный чугун  \
# Цена на арматуру                                                             0.659158
# Price_x                                                                      0.777963
# Open_x                                                                       0.779960
# High_x                                                                       0.774661
# Low_x                                                                        0.784654
# ...                                                                               ...
# Экспорт сырья Чугун_Передельный чугун                                        1.000000
# Экспорт арматуры Сортовой прокат_Арматура                                    0.967501
# Экспорт арматуры Сортовой прокат_Катанка                                     0.751514
# Экспорт арматуры Сортовой прокат_Прутки прочие                              -0.352181
# month                                                                        0.139673
#
#                                                 Экспорт арматуры Сортовой прокат_Арматура  \
# Цена на арматуру                                                                 0.615961
# Price_x                                                                          0.723272
# Open_x                                                                           0.726843
# High_x                                                                           0.720093
# Low_x                                                                            0.732079
# ...                                                                                   ...
# Экспорт сырья Чугун_Передельный чугун                                            0.967501
# Экспорт арматуры Сортовой прокат_Арматура                                        1.000000
# Экспорт арматуры Сортовой прокат_Катанка                                         0.665856
# Экспорт арматуры Сортовой прокат_Прутки прочие                                  -0.484789
# month                                                                            0.156516
#
#                                                 Экспорт арматуры Сортовой прокат_Катанка  \
# Цена на арматуру                                                                0.683340
# Price_x                                                                         0.759985
# Open_x                                                                          0.761062
# High_x                                                                          0.758229
# Low_x                                                                           0.758518
# ...                                                                                  ...
# Экспорт сырья Чугун_Передельный чугун                                           0.751514
# Экспорт арматуры Сортовой прокат_Арматура                                       0.665856
# Экспорт арматуры Сортовой прокат_Катанка                                        1.000000
# Экспорт арматуры Сортовой прокат_Прутки прочие                                 -0.010326
# month                                                                           0.098312
#
#                                                 Экспорт арматуры Сортовой прокат_Прутки прочие  \
# Цена на арматуру                                                                     -0.043717
# Price_x                                                                              -0.117278
# Open_x                                                                               -0.115834
# High_x                                                                               -0.111277
# Low_x                                                                                -0.123669
# ...                                                                                        ...
# Экспорт сырья Чугун_Передельный чугун                                                -0.352181
# Экспорт арматуры Сортовой прокат_Арматура                                            -0.484789
# Экспорт арматуры Сортовой прокат_Катанка                                             -0.010326
# Экспорт арматуры Сортовой прокат_Прутки прочие                                        1.000000
# month                                                                                 0.031873
#
#                                                    month
# Цена на арматуру                               -0.011973
# Price_x                                        -0.026898
# Open_x                                         -0.035655
# High_x                                         -0.037214
# Low_x                                          -0.022128
# ...                                                  ...
# Экспорт сырья Чугун_Передельный чугун           0.139673
# Экспорт арматуры Сортовой прокат_Арматура       0.156516
# Экспорт арматуры Сортовой прокат_Катанка        0.098312
# Экспорт арматуры Сортовой прокат_Прутки прочие  0.031873
# month                                           1.000000
#
# [151 rows x 151 columns]

# %%
# Шаг 1: Удаление признаков с высокой мультиколлинеарностью
# Оставляем только один из Price_x, Open_x, High_x, Low_x
df = df.drop(columns=['Open_x', 'High_x', 'Low_x'])  # Удаляем все, кроме Price_x

# Шаг 2: Удаление признаков с очень слабой корреляцией
# Вычисляем корреляцию с целевой переменной
corr_with_target = df.corr()['Цена на арматуру'].abs()

# Удаляем признаки с корреляцией < 0.1
weak_features = corr_with_target[corr_with_target < 0.1].index
df = df.drop(columns=weak_features)

# Вывод результата
print("Очищенные данные:")
print(df.head())  # Показываем первые строки очищенного DataFrame
# Out:
# Очищенные данные:
#           dt  Цена на арматуру  Price_x    Vol._x  Change %_x    Цена   Откр.  \
# 0 2015-01-05             32900   1029.8  929280.0        2.82  4470.0  4380.0
# 1 2015-01-12             32500   1029.8  929280.0        2.82  4470.0  4380.0
# 2 2015-01-19             32000   1029.8  929280.0        2.82  4470.0  4380.0
# 3 2015-01-26             30700   1029.8  929280.0        2.82  4470.0  4380.0
# 4 2015-02-02             30300   1029.8  929280.0        2.82  4470.0  4380.0
#
#     Макс.    Мин.         Объём  ...  Экспорт сырья ЖРС_Концентрат  \
# 0  4480.0  4373.0  1.134000e+09  ...                           5.0
# 1  4480.0  4373.0  1.134000e+09  ...                           5.0
# 2  4480.0  4373.0  1.134000e+09  ...                           5.0
# 3  4480.0  4373.0  1.134000e+09  ...                           5.0
# 4  4480.0  4373.0  1.134000e+09  ...                           5.0
#
#    Экспорт сырья ЖРС_Окатыши  Экспорт сырья Кокс_Мелочь коксовая  \
# 0                      131.0                                10.0
# 1                      131.0                                10.0
# 2                      131.0                                10.0
# 3                      131.0                                10.0
# 4                      131.0                                10.0
#
#    Экспорт сырья Концентрат коксующегося угля_Жирные  \
# 0                                                4.0
# 1                                                4.0
# 2                                                4.0
# 3                                                4.0
# 4                                                4.0
#
#    Экспорт сырья Концентрат коксующегося угля_Коксовые  \
# 0                                              115.0
# 1                                              115.0
# 2                                              115.0
# 3                                              115.0
# 4                                              115.0
#
#    Экспорт сырья Лом_Лом стальной  Экспорт сырья Чугун_Литейный чугун  \
# 0                             1.0                                 6.0
# 1                             1.0                                 6.0
# 2                             1.0                                 6.0
# 3                             1.0                                 6.0
# 4                             1.0                                 6.0
#
#    Экспорт сырья Чугун_Передельный чугун  \
# 0                                   23.0
# 1                                   23.0
# 2                                   23.0
# 3                                   23.0
# 4                                   23.0
#
#    Экспорт арматуры Сортовой прокат_Арматура  \
# 0                                      102.0
# 1                                      102.0
# 2                                      102.0
# 3                                      102.0
# 4                                      102.0
#
#    Экспорт арматуры Сортовой прокат_Катанка
# 0                                      62.0
# 1                                      62.0
# 2                                      62.0
# 3                                      62.0
# 4                                      62.0
#
# [5 rows x 138 columns]

# %%
from statsmodels.tsa.stattools import adfuller

def check_stationarity(series):
    result = adfuller(series.dropna())  # ADF-тест
    print("ADF Statistic:", result[0])
    print("p-value:", result[1])
    if result[1] < 0.05:
        print("Ряд стационарный")
    else:
        print("Ряд НЕ стационарный, требуется преобразование")
def check_stationarity(series):
    result = adfuller(series.dropna())  # ADF-тест
    print("ADF Statistic:", result[0])
    print("p-value:", result[1])
    if result[1] < 0.05:
        print("Ряд стационарный")
    else:
        print("Ряд НЕ стационарный, требуется преобразование")

# Проверяем
check_stationarity(df["Цена на арматуру"])
# Out:
# ADF Statistic: -1.5484468381220473
# p-value: 0.5094239275287091
# Ряд НЕ стационарный, требуется преобразование

# %%
# Проверяем стационарность всех переменных
for col in df.columns:
    if df[col].dropna().nunique() <= 1:
        print(f'{col}: Constant - skipping ADF test')
        continue
    result = adfuller(df[col].dropna())
    print(f'{col}: p-value = {result[1]}')
    if result[1] > 0.05:
        df[col] = df[col].diff()
# Out:
# dt: p-value = 0.9553456276134091
# Цена на арматуру: p-value = 0.5094239275287091
# Price_x: p-value = 0.028528560440732022
# Vol._x: p-value = 0.1459816214031619
# Change %_x: p-value = 0.03660167765493671
# Цена: p-value = 0.18737106146737398
# Откр.: p-value = 0.17496671772110212
# Макс.: p-value = 0.1847577580715113
# Мин.: p-value = 0.17192246192776867
# Объём: p-value = 1.1368280673492362e-05
# Изм. %: p-value = 0.11149842352638467
# Price_y: p-value = 0.07808156491053234
# Open_y: p-value = 0.08471490408910082
# High_y: p-value = 0.07340887539360223
# Low_y: p-value = 0.09073087620502257
# Vol._y: p-value = 0.17868675813451812
# Change %_y: p-value = 2.1949272070859955e-08
# Импорт цемента ЖД: p-value = 0.6629026033082743
# Экспорт цемента ЖД: p-value = 0.16072811962011974
# Отгрузка цемента хоппер ЖД: p-value = 0.5983872778695484
# Отгрузка цемента остальные ЖД: p-value = 0.08760490680977506
# Производство цемента: p-value = 0.21660713838271373
# Импорт цемента: p-value = 0.2230043335589067
# Экспорт цемента: p-value = 0.1342442451816535
# Потребление цемента: p-value = 0.21303466934243864
# Отгрузка цемента: p-value = 0.20620180828002904
# Цена цемента с НДС: p-value = 0.724748923383785
# Цена цемента без НДС: p-value = 0.23925001110255406
# Производство бетона РФ: p-value = 0.185062760282025
# Производство бетона МО: p-value = 0.2498653000217017
# Производство бетона СПБ: p-value = 0.653982486151504
# Концентрат коксующегося угля_Россия марка ОС FCA руб./т, без НДС: p-value = 0.06458852690380262
# Лом_HMS 1/2 80:20, FOB EC Роттердам, $/т: p-value = 0.24032980940709647
# Лом_3А, РФ CPT ж/д Южный ФО, руб./т, без НДС: p-value = 0.772203511460734
# Лом_3А, РФ CPT ж/д Сибирский ФО, руб./т, без НДС: p-value = 0.7183691073102195
# Лом_3А, РФ CPT ж/д Центральный ФО, руб./т, без НДС: p-value = 0.5888594295691333
# ЖРС_Китай Iron ore fines Fe 62%, CFR: p-value = 0.27912922522382183
# Чугун_CFR Италия, $/т: p-value = 0.5683351227953464
# Концентрат коксующегося угля_Россия марка КО FCA руб./т, без НДС: p-value = 0.24275583948646373
# ЖРС_Российские окатыши Fe 62-65,5%, SiO2 5,8-8,65, DAP Забайкальск-Манжули, $/т: p-value = 0.4438691475077307
# Лом_HMS 1/2 80:20, FOB США Восток, $/т: p-value = 0.38361209383008354
# Лом_3А, FOB РФ Черное море, $/т: p-value = 0.29585312570918854
# Чугун_FOB Бразилия Север, $/т: p-value = 0.41284231191871007
# Лом_HMS 1/2 80:20, CFR ЮВА, $/т: p-value = 0.3885512047239904
# Концентрат коксующегося угля_Россия марка КС FCA руб./т, без НДС: p-value = 0.04656080328823083
# Лом_3А, РФ FCA ж/д респ. Татарстан, руб./т, без НДС: p-value = 0.7233975917401669
# ЖРС_Российский концентрат Fe 62,5-67,5%, SiO2 0,78-8,51, сухой вес, DAP Забайкальск-Манжули, $/т: p-value = 0.26066149329431504
# Концентрат коксующегося угля_Россия марка К и смеси марок К, КО FCA руб./т, без НДС: p-value = 0.013824256261958693
# Кокс_Россия Урал Сибирь +25, FCA руб./т., без НДС: p-value = 0.060234942840435186
# Лом_3А, РФ FCA ж/д Московский регион, руб./т, без НДС: p-value = 0.6533091267540123
# Концентрат коксующегося угля_Россия марка Ж+ГЖ FCA руб./т, без НДС: p-value = 0.14088139329433114
# Чугун_FOB Россия Черное море, $/т: p-value = 0.39851690816206276
# ЖРС_Россия аглоруда Fe 52-60%, FCA руб./т, без НДС: p-value = 0.25582798985936184
# ЖРС_Россия концентрат Fe 64-68%, FCA руб./т, без НДС: p-value = 0.4868228455804369
# Чугун_Россия, FCA руб./т, без НДС: p-value = 0.1575816970002321
# Концентрат коксующегося угля_HCC Австралия, $/t FOB: p-value = 0.3917600432941673
# ЖРС_Россия окатыши Fe 62-65,5% FCA руб./т, без НДС: p-value = 0.49161315510000686
# ГБЖ_CFR Италия, $/т: p-value = 0.5318635014243616
# Лом_3А, РФ CPT ж/д Уральский ФО, руб./т, без НДС: p-value = 0.7717078794856163
# Концентрат коксующегося угля_Россия марка Ж FCA руб./т, без НДС: p-value = 0.20124196146304152
# Лом_HMS 1/2 80:20, CFR Турция, $/т: p-value = 0.4524825165911096
# Чугун_CFR Китай, $/т: p-value = 0.6029433135993064
# Концентрат коксующегося угля_Средняя шихта Россия FCA руб./т, без НДС: p-value = 0.013494187580549625
# Концентрат коксующегося угля_Россия марка ГЖ FCA руб./т, без НДС: p-value = 0.01231837925640008
# Чугун_CFR NOLA США, $/т: p-value = 0.47784740778318446
# Чугун_CFR Турция, $/т: p-value = 0.4503846845618079
# ЖРС_Средневзвешенная цена окатыши Fe 62-65,5%, Россия FCA руб./т, без НДС: p-value = 0.4946896477783953
# ЖРС_Средневзвешенная цена концентрат Fe 64-68%, Россия FCA руб./т, без НДС: p-value = 0.4940386505158436
# ЖРС_Средневзвешенная цена аглоруда Fe 52-60%, Россия FCA руб./т, без НДС: p-value = 0.43581852369788104
# ЖРС_Средневзвешенная цена за 1 % Fe в аглоруде, Россия FCA руб./т, без НДС: p-value = 0.5156502173925512
# ЖРС_Средневзвешенная цена за 1 % Fe в концентрате, Россия FCA руб./т, без НДС: p-value = 0.3205096557174636
# ЖРС_Средневзвешенная цена за 1 % Fe в окатыши, Россия FCA руб./т, без НДС: p-value = 0.3787830179042916
# ЖРС_Украинский концентрат Fe 65-68%,  DAP граница Украины с Европой,  $/т: p-value = 0.1908534490408782
# ЖРС_Украинские окатыши Fe 65-66%, DAP граница Украины с Европой,  $/т: p-value = 0.22022921827836434
# Цена на бензин: p-value = 0.977539825583263
# Цена на дт: p-value = 0.9683286876499861
# Производство арматуры Сортовой прокат_Арматура: p-value = 0.4274681142169814
# Производство арматуры Сортовой прокат_Катанка: p-value = 0.6769444937072141
# Производство арматуры Сортовой прокат_Прутки прочие: p-value = 0.1805739578542072
# Производство сырья ЖРС_Агломерат: p-value = 0.49815453404984744
# Производство сырья ЖРС_Аглоруда: p-value = 0.6087623575999854
# Производство сырья ЖРС_Концентрат: p-value = 0.2327985329670899
# Производство сырья ЖРС_Концентрат для дообогащения: p-value = 0.44883640420032567
# Производство сырья ЖРС_Окатыши: p-value = 0.3033133068954259
# Производство сырья Кокс_Кокс валовый: p-value = 0.29178424207507503
# Производство сырья Концентрат коксующегося угля_Жирные: p-value = 0.9639198587247771
# Производство сырья Концентрат коксующегося угля_Отощающие: p-value = 0.4722095445835488
# Производство сырья Металлизованная продукция_ГБЖ: p-value = 0.17165714778175245
# Производство сырья Металлизованная продукция_ПВЖ: p-value = 0.29266560821989385
# Производство сырья Рядовой коксующийся уголь_Газовые: p-value = 0.15547551181966662
# Производство сырья Рядовой коксующийся уголь_Жирные: p-value = 0.968348238919839
# Производство сырья Рядовой коксующийся уголь_Отощающие: p-value = 0.4284453712061601
# Производство сырья Сталь_Конвертер: p-value = 0.7916735504987469
# Производство сырья Сталь_Мартен: p-value = 0.2607209871076681
# Производство сырья Сталь_Сталь всего: p-value = 0.6605274755181506
# Производство сырья Сталь_Электропечь: p-value = 0.3584257491793626
# Производство сырья Чугун_Чугун: p-value = 0.5656757110312859
# ПотреблениеЖРС_Агломерат: p-value = 0.7588835755424258
# ПотреблениеЖРС_Окатыши: p-value = 0.5654730929368121
# ПотреблениеЖРС_Концентрат для дообогащения: p-value = 0.19189681700132966
# ПотреблениеЖРС_Аглоруда: p-value = 0.3984709960477772
# Поставки Сортовой прокат_Арматура: p-value = 0.37572828135113173
# Поставки Сортовой прокат_Катанка: p-value = 0.6080861064458175
# Поставки Сортовой прокат_Прутки прочие: p-value = 0.02899834939535294
# Поставки Концентрат коксующегося угля_Жирные: p-value = 0.35295604119610535
# Поставки Концентрат коксующегося угля_Коксовые: p-value = 0.29084956773501536
# Поставки Концентрат коксующегося угля_Отощающие: p-value = 0.9761964616087168
# Поставки Чугун_Литейный чугун: p-value = 0.1951018502245111
# Поставки Чугун_Передельный чугун: p-value = 0.45929263964196904
# Поставки ЖРС_Агломерат: p-value = 0.7524298309653595
# Поставки ЖРС_Аглоруда: p-value = 0.4110290896939804
# Поставки ЖРС_Концентрат: p-value = 0.13443238982132438
# Поставки ЖРС_Концентрат для дообогащения: p-value = 0.18817390513573784
# Поставки ЖРС_Окатыши: p-value = 0.4616187294883201
# Спрос ЖРС_Агломерат: p-value = 0.7524298309653595
# Спрос ЖРС_Аглоруда: p-value = 0.4110290896939804
# Спрос ЖРС_Концентрат для дообогащения: p-value = 0.23013130725587322
# Спрос ЖРС_Окатыши: p-value = 0.4546415234990422
# Спрос Металлизованная продукция_ГБЖ: p-value = 0.1711537522174093
# Спрос Концентрат коксующегося угля_Жирные: p-value = 0.08118821816762589
# Спрос Концентрат коксующегося угля_Коксовые: p-value = 0.23577801493474526
# Спрос Концентрат коксующегося угля_Отощающие: p-value = 0.9761964616087168
# Импорт сырья ЖРС_Концентрат: p-value = 0.21002958557644646
# Импорт сырья ЖРС_Окатыши: p-value = 0.4491104346339856
# Импорт сырья Концентрат коксующегося угля_Коксовые: p-value = 0.061694857132784
# Импорт арматуры Сортовой прокат_Катанка: p-value = 0.2959702230294924
# Импорт арматуры Сортовой прокат_Прутки прочие: p-value = 0.07609728019657519
# Экспорт сырья ЖРС_Аглоруда: p-value = 0.6714020394998821
# Экспорт сырья ЖРС_Концентрат: p-value = 0.42030987097542727
# Экспорт сырья ЖРС_Окатыши: p-value = 0.2737667437778435
# Экспорт сырья Кокс_Мелочь коксовая: p-value = 0.3654604611894625
# Экспорт сырья Концентрат коксующегося угля_Жирные: p-value = 0.474786801698218
# Экспорт сырья Концентрат коксующегося угля_Коксовые: p-value = 0.3149931621347663
# Экспорт сырья Лом_Лом стальной: Constant - skipping ADF test
# Экспорт сырья Чугун_Литейный чугун: p-value = 0.9283392398286062
# Экспорт сырья Чугун_Передельный чугун: p-value = 0.29187466487712577
# Экспорт арматуры Сортовой прокат_Арматура: p-value = 0.3383288733541514
# Экспорт арматуры Сортовой прокат_Катанка: p-value = 0.16522138161015826

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.figure(figsize=(12, 6))

plt.subplot(1,2,1)
plot_acf(df["Цена_diff"].dropna(), lags=40, ax=plt.gca())  # ACF
plt.title("Автокорреляционная функция (ACF)")

plt.subplot(1,2,2)
plot_pacf(df["Цена_diff"].dropna(), lags=40, ax=plt.gca())  # PACF
plt.title("Частичная автокорреляция (PACF)")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Цена_diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-3ec881988157> in <cell line: 0>()
#       4
#       5 plt.subplot(1,2,1)
# ----> 6 plot_acf(df["Цена_diff"].dropna(), lags=40, ax=plt.gca())  # ACF
#       7 plt.title("Автокорреляционная функция (ACF)")
#       8
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Цена_diff'

# %% [markdown]
# ACF медленно затухает, что подтверждает нестационарность ряда
#
# PACF имеет значимые лаги на 1 и 2 (возможно AR(2) процесс)
#
# Сезонные пики через регулярные промежутки (например, лаг 12 для месячных данных)

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
df = df.dropna()
# Построение графика динамики цен
plt.figure(figsize=(12, 6))
plt.plot(df.index, df["Цена_diff"], label="Цена_diff", color="blue")
plt.xlabel("Дата")
plt.ylabel("Цена (руб.)")
plt.title("Динамика цен на арматуру")

plt.figure(figsize=(12, 6))
plt.plot(df.index, df["Цена_diff"], label="Цена_diff", color="blue")
plt.xlabel("Дата")
plt.ylabel("Цена (руб.)")
plt.title("Динамика цен на арматуру (2015-2023)")
plt.legend()
plt.grid(True)
plt.show()

# Разложение временного ряда на тренд, сезонность и остатки
decomposition = seasonal_decompose(df["Цена_diff"], period=52, model="additive")
decomposition.plot()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import periodogram

# Предположим, что у вас есть временной ряд 'Цена_diff'
f, Pxx = periodogram(df["Цена на арматуру"].dropna())

plt.figure(figsize=(10, 5))
plt.plot(f, Pxx)
plt.xlabel("Частота")
plt.ylabel("Энергия спектра")
plt.title("Периодограмма ряда")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(df["dt"], df["Цена на арматуру"])
plt.xlabel("Дата")
plt.ylabel("Цена")
plt.title("График временного ряда")
plt.show()

# %% [markdown]
# Наблюдается нестационарность ряда с выраженным трендом (долгосрочный рост цен)
#
# Присутствуют сезонные колебания (периодические всплески и спады)
#
# Возможны структурные изменения (резкие скачки, возможно связанные с внешними факторами)

# %%
# !pip install xgboost

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
# import pandas as pd
# import numpy as np
# from sklearn.model_selection import train_test_split, GridSearchCV
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.metrics import mean_absolute_error
# import matplotlib.pyplot as plt

# # Загрузка данных # Замените на свой путь к данным
# df['dt'] = pd.to_datetime(df['dt'])  # Преобразуем столбец с датой в datetime

# df = df.sort_values(by='dt')

# # Создание временных признаков
# df['year'] = df['dt'].dt.year
# df['month'] = df['dt'].dt.month
# df['week'] = df['dt'].dt.isocalendar().week
# df['quarter'] = df['dt'].dt.quarter

# # Скользящие средние
# df['rolling_mean_4'] = df['Цена на арматуру'].rolling(window=4, min_periods=1).mean()
# df['rolling_mean_8'] = df['Цена на арматуру'].rolling(window=8, min_periods=1).mean()
# df['rolling_mean_12'] = df['Цена на арматуру'].rolling(window=12, min_periods=1).mean()

# # Разности цен
# df['diff_1'] = df['Цена на арматуру'].diff(1)
# df['diff_4'] = df['Цена на арматуру'].diff(4)
# df['diff_8'] = df['Цена на арматуру'].diff(8)

# # Убираем пропущенные значения
# df = df.dropna()

# # Выбираем целевую переменную и признаки
# target = 'Цена на арматуру'
# features = [col for col in df.columns if col not in ['dt', target]]

# # Разделение на обучающую и тестовую выборки
# train_df = df[:-10]  # Используем все, кроме последних 10 недель, для обучения
# test_df = df[-10:]  # Последние 10 недель для тестирования

# X_train, y_train = train_df[features], train_df[target]
# X_test, y_test = test_df[features], test_df[target]

# # Определим параметры для поиска
# param_grid = {
#     'n_estimators': [50, 100, 150, 200],
#     'max_depth': [None, 10, 20, 30],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4]
# }

# # Создаем модель RandomForestRegressor
# model = RandomForestRegressor(random_state=42)

# # Настройка GridSearchCV
# grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2, scoring='neg_mean_absolute_error')

# # Обучаем модель с GridSearchCV
# grid_search.fit(X_train, y_train)

# # Выводим лучшие параметры
# print("Лучшие параметры: ", grid_search.best_params_)

# # Прогнозирование с лучшими параметрами
# best_model = grid_search.best_estimator_
# y_pred = best_model.predict(X_test)

# # Оценка модели
# mae = mean_absolute_error(y_test, y_pred)
# print(f'MAE после настройки гиперпараметров: {mae}')

# # Прогнозирование без настройки гиперпараметров для сравнения
# baseline_model = RandomForestRegressor(random_state=42)
# baseline_model.fit(X_train, y_train)
# y_baseline_pred = baseline_model.predict(X_test)
# baseline_mae = mean_absolute_error(y_test, y_baseline_pred)
# print(f'MAE базовой модели: {baseline_mae}')

# # Процент улучшения
# improvement_percentage = ((baseline_mae - mae) / baseline_mae) * 100
# print(f'Процент улучшения MAE: {improvement_percentage:.2f}%')

# # Построение графика
# plt.figure(figsize=(10, 6))
# plt.plot(test_df['dt'], y_test, label='Истинные значения', marker='o')
# plt.plot(test_df['dt'], y_pred, label='Прогноз (с гиперпараметрами)', linestyle='--', marker='x', color='red')
# plt.plot(test_df['dt'], y_baseline_pred, label='Прогноз (без гиперпараметров)', linestyle='--', marker='x', color='blue')
# plt.title('Прогнозирование рыночных цен на арматуру')
# plt.xlabel('Дата')
# plt.ylabel('Цена на арматуру')
# plt.legend()
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, TimeSeriesSplit, GridSearchCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Загрузка данных (замените на ваш путь)
# df = pd.read_csv('your_data.csv')
df['dt'] = pd.to_datetime(df['dt'])  # Преобразуем столбец с датой в datetime
df = df.sort_values(by='dt').set_index('dt')

# 1. Анализ временного ряда
decomposition = seasonal_decompose(df['Цена на арматуру'], period=12)
decomposition.plot()
plt.show()

# 2. Создание расширенных временных признаков
def create_features(df):
    df = df.copy()
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['week'] = df.index.isocalendar().week
    df['quarter'] = df.index.quarter
    df['dayofyear'] = df.index.dayofyear
    df['lag1'] = df['Цена на арматуру'].shift(1)
    df['lag4'] = df['Цена на арматуру'].shift(4)
    df['lag8'] = df['Цена на арматуру'].shift(8)
    df['rolling_mean_4'] = df['Цена на арматуру'].rolling(window=4).mean()
    df['rolling_std_4'] = df['Цена на арматуру'].rolling(window=4).std()
    df['rolling_mean_12'] = df['Цена на арматуру'].rolling(window=12).mean()
    df['ewm'] = df['Цена на арматуру'].ewm(span=12, adjust=False).mean()
    return df

df = create_features(df)
df = df.dropna()

# 3. Разделение данных с учетом временного ряда
target = 'Цена на арматуру'
features = [col for col in df.columns if col != target]

# Используем TimeSeriesSplit для кросс-валидации
train_size = int(len(df) * 0.85)
train_df = df.iloc[:train_size]
test_df = df.iloc[train_size:]

X_train, y_train = train_df[features], train_df[target]
X_test, y_test = test_df[features], test_df[target]

# 4. Создание конвейера с масштабированием и моделью
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', RandomForestRegressor(random_state=42, n_jobs=-1))
])

# 5. Улучшенная сетка параметров
param_grid = {
    'model__n_estimators': [100, 200, 300],
    'model__max_depth': [None, 10, 20, 30],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4],
    'model__max_features': ['sqrt', 'log2', 0.5]
}

# 6. Используем TimeSeriesSplit для кросс-валидации
tscv = TimeSeriesSplit(n_splits=5)

# 7. Настройка GridSearchCV
grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=tscv,
    n_jobs=-1,
    verbose=1,
    scoring='neg_mean_absolute_error'
)

# 8. Обучение модели
grid_search.fit(X_train, y_train)

# 9. Оценка модели
best_model = grid_search.best_estimator_
print("Лучшие параметры: ", grid_search.best_params_)

# Прогнозирование
y_pred = best_model.predict(X_test)

# Метрики
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f'MAE: {mae:.2f}')
print(f'RMSE: {rmse:.2f}')

# 10. Сравнение с базовой моделью
baseline_pred = np.roll(y_test, 1)  # Простое предсказание "завтра как сегодня"
baseline_mae = mean_absolute_error(y_test[1:], baseline_pred[1:])
print(f'MAE базовой модели (persistence): {baseline_mae:.2f}')

# 11. Визуализация
plt.figure(figsize=(12, 6))
plt.plot(test_df.index, y_test, label='Истинные значения', marker='o')
plt.plot(test_df.index, y_pred, label='Прогноз', linestyle='--', marker='x', color='red')
plt.title('Прогнозирование цен на арматуру')
plt.xlabel('Дата')
plt.ylabel('Цена')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 12. Анализ важности признаков
if hasattr(best_model.named_steps['model'], 'feature_importances_'):
    feature_importances = pd.DataFrame({
        'feature': features,
        'importance': best_model.named_steps['model'].feature_importances_
    }).sort_values('importance', ascending=False)

    plt.figure(figsize=(10, 6))
    plt.barh(feature_importances['feature'][:10], feature_importances['importance'][:10])
    plt.title('Топ-10 важных признаков')
    plt.xlabel('Важность')
    plt.tight_layout()
    plt.show()
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Лучшие параметры:  {'model__max_depth': None, 'model__max_features': 0.5, 'model__min_samples_leaf': 4, 'model__min_samples_split': 10, 'model__n_estimators': 300}
# MAE: 4688.16
# RMSE: 6073.10
# MAE базовой модели (persistence): 4065.52
